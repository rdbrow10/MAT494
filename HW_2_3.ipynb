# %% [markdown]
# <a href="https://colab.research.google.com/github/rdbrow10/MAT494/blob/main/HW_2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  nbformat: 4,
  nbformat_minor: 0,
  metadata: {
    colab: {
    name: 'HW2_3'
    provenance: []
    collapsed_sections: []
    }
    kernelspec: {
      name: python3
      display_name: "Python 3"
    }
    language_info: {
      name: python
    }
  }
  cells: [
    {
      cell_type: code
      metadata: {
        colab: {
          base_uri: 'https://localhost:8080/'
        }
        id: UopzLqtrz6ne
        outputId: '80ca3c9c-f5f1-43c0-aac1-6b5d5d2f1140'
      }
      source: [
        # Importing random variables
        import random
        value=random.uniform(1,100)
        print(value)
      ]
      execution_count: 2
      outputs: [
        {
          output_type: stream
          name: stdout
          text: [
            58.9307361512367
          ]
        }
      ]
    },
    {
      cell_type: code
      metadata: {
        colab: {
          base_uri: https://localhost:8080/
        }
        id: VfXlqN5d4Iar,
        outputId: 32cc34e2-a801-4636-c2cb-0dc69d0ec918
      }
      source: [
        coin=['Head','Tails']
        results=random.choices(coin, k=5)
        print(results)
      ]
      execution_count: 6
      outputs: [
        {
          output_type: stream
          name: stdout
          text: [
            ['Head', 'Tails', 'Tails', 'Head', 'Tails']
          ]
        }
      ]
    }
    {
      cell_type: code
      metadata: {
        colab: {
          base_uri: https://localhost:8080/
          height: 283
        }
        id: -HtJxBPs49t4
        outputId: 7e55c348-adff-4bf3-b6a0-37e36153ed3e
      }
      source: [
        # Making Regression Models\n
        import pandas as pd
        import numpy as np
        import matplotlib.pyplot as plt
        from sklearn import linear_model
        from sklearn.linear_model import LinearRegression
        
        x=np.array([1,2,2,2,3,3,4,4,4,4,5,6,6,7,9,9,10,10])
        y=np.array([23,25,26,21,37,32,27,25,33,41,49,45,61,52,65,59,77,61])
        
        linreg=LinearRegression()
        x=x.reshape(-1,1)
        linreg.fit(x,y)
        y_pred=linreg.predict(x)
        plt.scatter(x,y)
        plt.plot(x,y_pred,color='blue')
      ]
      execution_count: 22
      outputs: [
        {
          output_type: execute_result
          data: {
            text/plain: [
              [<matplotlib.lines.Line2D at 0x7f97071823d0>]
            ]
          }
          metadata: {}
          execution_count: 22
        }
        {
          output_type: display_data
          data: {
            image/png: ...\n",
            text/plain: [
              <Figure size 432x288 with 1 Axes>
            ]
          }
          metadata: {
            needs_background: light
          }
        }
      ]
    }
    {
      cell_type: code
      metadata: {
        colab: {
          base_uri: https://localhost:8080/
        }
        id: n-7cXDxx_3FR
        outputId: 1af793dc-830f-4efc-eb66-d1af9021b9eb
      }
      source: [
        print(linreg.coef_)
      ]
      execution_count: 23
      outputs: [
        {
          output_type: stream
          name: stdout
          text: [
            [5.46949087]
          ]
        }
        ]
    }
  ]
}
# Out:
#   File "<ipython-input-1-75fdc8285503>", line 7
#     provenance: []
#              ^
# SyntaxError: invalid syntax
